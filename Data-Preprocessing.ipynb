# %% [markdown]
# # Ghana Conflict Event
# ## Data Preprocessing
#
# **Author:** Abdel An'lah TIDJANI
#
# **Date:** December 31,2021

# %% [markdown]
# ### Notebook Configuration

# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
# Configure notebook output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Number of rows and columns
pd.set_option('display.max_rows', 150)
pd.set_option('display.max_columns', 150)

# %% [markdown]
# ### Load Data

# %%
# Load data
dataset_name = 'data/1980-11-04-2021-11-13-Ghana.csv'
df = pd.read_csv(dataset_name, sep=";")

# %% [markdown]
# ### Inspect the Structure
# The data frame contains 37 attributes, and 1,276 observations.

# %%
print("Shape of the data:", df.shape)
Rows,Cols=df.shape
df.head()
# Out:
# Shape of the data: (1276, 31)
#    data_id  iso event_id_cnty  event_id_no_cnty        event_date  year  \
# 0  8628752  288       GHA1295              1295  04 November 2021  2021
# 1  8628433  288       GHA1296              1296  03 November 2021  2021
# 2  8628634  288       GHA1297              1297  03 November 2021  2021
# 3  8628753  288       GHA1298              1298  01 November 2021  2021
# 4  8628434  288       GHA1299              1299   30 October 2021  2021
#
#    time_precision event_type         sub_event_type  \
# 0               1   Protests       Peaceful protest
# 1               1      Riots  Violent demonstration
# 2               1   Protests       Peaceful protest
# 3               1      Riots           Mob violence
# 4               1    Battles            Armed clash
#
#                                    actor1  \
# 0                      Protesters (Ghana)
# 1                         Rioters (Ghana)
# 2                      Protesters (Ghana)
# 3                         Rioters (Ghana)
# 4  Nadu Warriors Communal Militia (Ghana)
#
#                                        assoc_actor_1  inter1  \
# 0  Christian Group (Ghana); Muslim Group (Ghana);...       6
# 1                               Labour Group (Ghana)       5
# 2                                                NaN       6
# 3                                                NaN       5
# 4                                                NaN       4
#
#                            actor2                            assoc_actor_2  \
# 0                             NaN                                      NaN
# 1  Police Forces of Ghana (2017-)                                      NaN
# 2                             NaN                                      NaN
# 3  Police Forces of Ghana (2017-)  Civilians (Ghana); Labour Group (Ghana)
# 4  Police Forces of Ghana (2017-)                                      NaN
#
#    inter2  interaction          region country    admin1         admin2  \
# 0       0           60  Western Africa   Ghana   Eastern  Akwapem North
# 1       1           15  Western Africa   Ghana   Central    Assin North
# 2       0           60  Western Africa   Ghana   Ashanti   Amansie West
# 3       1           15  Western Africa   Ghana  Northern         Tamale
# 4       1           14  Western Africa   Ghana   Eastern    Lower Manya
#
#    admin3      location  latitude  longitude  geo_precision  \
# 0     NaN        Larteh    5.9395    -0.0689              1
# 1     NaN  Assin Bereku    5.8678    -1.3389              1
# 2     NaN  Manso Atwere    6.4574    -1.8575              1
# 3     NaN        Tamale    9.4008    -0.8393              2
# 4     NaN         Krobo    6.1299     0.0012              1
#
#                          source source_scale  \
# 0                   GNA (Ghana)     National
# 1          Citi News; Ghana Web     National
# 2                     Citi News     National
# 3                   GNA (Ghana)     National
# 4  Ghana Web; Chronicle (Ghana)     National
#
#                                                notes  fatalities   timestamp  \
# 0  On 4 November 2021, members of the Presbyteria...           0  1636405422
# 1  On 3 November 2021, workers of the Shimizu Dai...           0  1636405421
# 2  On 3 November 2021, residents demonstrated in ...           0  1636405422
# 3  On 1 November 2021, residents of Kukuo suburb ...           0  1636405422
# 4  On 30 October 2021, members of the Nadu Warrio...           0  1636405421
#
#   iso3
# 0  GHA
# 1  GHA
# 2  GHA
# 3  GHA
# 4  GHA

# %%
# Display a summary of the data frame
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_id           1276 non-null   int64
#  1   iso               1276 non-null   int64
#  2   event_id_cnty     1276 non-null   object
#  3   event_id_no_cnty  1276 non-null   int64
#  4   event_date        1276 non-null   object
#  5   year              1276 non-null   int64
#  6   time_precision    1276 non-null   int64
#  7   event_type        1276 non-null   object
#  8   sub_event_type    1276 non-null   object
#  9   actor1            1276 non-null   object
#  10  assoc_actor_1     545 non-null    object
#  11  inter1            1276 non-null   int64
#  12  actor2            773 non-null    object
#  13  assoc_actor_2     288 non-null    object
#  14  inter2            1276 non-null   int64
#  15  interaction       1276 non-null   int64
#  16  region            1276 non-null   object
#  17  country           1276 non-null   object
#  18  admin1            1276 non-null   object
#  19  admin2            1276 non-null   object
#  20  admin3            0 non-null      float64
#  21  location          1276 non-null   object
#  22  latitude          1276 non-null   float64
#  23  longitude         1276 non-null   float64
#  24  geo_precision     1276 non-null   int64
#  25  source            1276 non-null   object
#  26  source_scale      1276 non-null   object
#  27  notes             1266 non-null   object
#  28  fatalities        1276 non-null   int64
#  29  timestamp         1276 non-null   int64
#  30  iso3              1276 non-null   object
# dtypes: float64(3), int64(11), object(17)
# memory usage: 309.2+ KB

# %% [markdown]
# ### View Missing Data
# Calculate the total number of null values and percent for each attribute.  As the results show, `"assoc_actor_1"`,  `"assoc_actor_2"`, and   `"admin3"`  are comprised of missing values of more than 50%.

# %%
# Check the number of missing values in each attribute
count = df.isnull().sum()
percent = round(count / Rows * 100, 2)
series = [count, percent]
result = pd.concat(series, axis=1, keys=['Count','Percent'])
result.sort_values(by='Count', ascending=False)
# Out:
#                   Count  Percent
# admin3             1276   100.00
# assoc_actor_2       988    77.43
# assoc_actor_1       731    57.29
# actor2              503    39.42
# notes                10     0.78
# data_id               0     0.00
# latitude              0     0.00
# admin2                0     0.00
# location              0     0.00
# longitude             0     0.00
# country               0     0.00
# geo_precision         0     0.00
# source                0     0.00
# source_scale          0     0.00
# fatalities            0     0.00
# timestamp             0     0.00
# admin1                0     0.00
# interaction           0     0.00
# region                0     0.00
# iso                   0     0.00
# inter2                0     0.00
# inter1                0     0.00
# actor1                0     0.00
# sub_event_type        0     0.00
# event_type            0     0.00
# time_precision        0     0.00
# year                  0     0.00
# event_date            0     0.00
# event_id_no_cnty      0     0.00
# event_id_cnty         0     0.00
# iso3                  0     0.00

# %%
# delete columns with more than 50% missing value
df.drop(columns = ["assoc_actor_1","assoc_actor_2","admin3"], inplace =True)

# %% [markdown]
# ### Looking at categorical features
# > low and high cardinality category features : `event_id_cnty`, `is03`, `region`, `country` don't give us useful information in this context of analysis.
#
# > `event_date` should be a date not object
#
# > According to  [codebook](ACLED_Codebook_2019FINAL.pdf)  `admin1` represent the county, `admin2` represent the state and `location` represent the neighborhood

# %%
df.select_dtypes('object').nunique().to_frame()
# Out:
#                    0
# event_id_cnty   1276
# event_date       970
# event_type         5
# sub_event_type    16
# actor1           127
# actor2            87
# region             1
# country            1
# admin1            16
# admin2           175
# location         337
# source           204
# source_scale      14
# notes           1236
# iso3               1

# %%
# delete columns with no useful information 
df.drop(columns = ["event_id_cnty","region","iso3","country"], inplace=True)

# %%
# convert event_date to datetime dtype
dateFormatter = "%d %B %Y"
df['event_date']=pd.to_datetime(df["event_date"], format=dateFormatter)

# %% [markdown]
# ### Looking at numeric features
# > `iso` , `time_precision`, `data_id`, `event_id_no_cnty`, `geo_precision`, `timestamp` don't give use useful information
#
# > According to the [codebook](ACLED_Codebook_2019FINAL.pdf) , `inter1`, `inter2`, and `interaction` shouldn't be consider as numeric because they have label
#
# > Good numeric features are  `year`, `latitude`, `longitude`, and `fatalities`

# %%
df.select_dtypes('number').describe()
# Out:
#             data_id     iso  event_id_no_cnty         year  time_precision  \
# count  1.276000e+03  1276.0       1276.000000  1276.000000     1276.000000
# mean   6.721911e+06   288.0        655.183386  2016.603448        1.158307
# std    1.113512e+06     0.0        376.729469     4.624347        0.371559
# min    4.555287e+06   288.0          1.000000  1997.000000        1.000000
# 25%    5.758440e+06   288.0        330.750000  2015.000000        1.000000
# 50%    7.060988e+06   288.0        658.500000  2018.000000        1.000000
# 75%    7.764179e+06   288.0        982.250000  2020.000000        1.000000
# max    8.638703e+06   288.0       1301.000000  2021.000000        3.000000
#
#             inter1       inter2  interaction     latitude    longitude  \
# count  1276.000000  1276.000000  1276.000000  1276.000000  1276.000000
# mean      4.732759     2.826803    44.356583     6.954875    -0.787464
# std       1.503426     3.001271    17.778258     1.772151     0.860652
# min       1.000000     0.000000    10.000000     4.794900    -3.045400
# 25%       4.000000     0.000000    37.000000     5.556000    -1.621800
# 50%       5.000000     1.000000    50.000000     6.357850    -0.483900
# 75%       6.000000     7.000000    60.000000     7.643375    -0.196900
# max       8.000000     8.000000    78.000000    11.084600     1.190100
#
#        geo_precision   fatalities     timestamp
# count    1276.000000  1276.000000  1.276000e+03
# mean        1.159875     0.528213  1.598546e+09
# std         0.418574     3.897911  2.557157e+07
# min         1.000000     0.000000  1.552576e+09
# 25%         1.000000     0.000000  1.572404e+09
# 50%         1.000000     0.000000  1.618269e+09
# 75%         1.000000     0.000000  1.618530e+09
# max         3.000000   126.000000  1.636413e+09

# %%
# drop numeric features with no useful information 
df.drop(columns = ["data_id", "iso", "event_id_no_cnty","time_precision","timestamp","geo_precision"] , inplace=True)

# %% [markdown]
# ### Let create new variable `interact`  labeled variable of `interaction`

# %%
# new variable interact

key = [10,11,12,13,14,15,16,17,18,20,22,23,24,25,26,27,28,30,33,34,35,36,37,38,40,44,45,46,47,48,50,55,56,57,58,60,66,67,68,78,80]

value = ["SOLE MILITARY ACTION","MILITARY VERSUS MILITARY","MILITARY VERSUS REBELS","MILITARY VERSUS POLITICAL MILITIA",
  "MILITARY VERSUS COMMUNAL MILITIA","MILITARY VERSUS RIOTERS","MILITARY VERSUS PROTESTERS","MILITARY VERSUS CIVILIANS",
  "MILITARY VERSUS OTHER","SOLE REBEL ACTION","REBELS VERSUS REBELS","REBELS VERSUS POLITICAL MILIITA","REBELS VERSUS COMMUNAL MILITIA",
  "REBELS VERSUS RIOTERS","REBELS VERSUS PROTESTERS","REBELS VERSUS CIVILIANS","REBELS VERSUS OTHERS","SOLE POLITICAL MILITIA ACTION",
  "POLITICAL MILITIA VERSUS POLITICAL MILITIA","POLITICAL MILITIA VERSUS COMMUNAL MILITIA","POLITICAL MILITIA VERSUS RIOTERS",
  "POLITICAL MILITIA VERSUS PROTESTERS","POLITICAL MILITIA VERSUS CIVILIANS","POLITICAL MILITIA VERSUS OTHERS","SOLE COMMUNAL MILITIA ACTION",
  "COMMUNAL MILITIA VERSUS COMMUNAL MILITIA","COMMUNAL MILITIA VERSUS RIOTERS","COMMUNAL MILITIA VERSUS PROTESTERS","COMMUNAL MILITIA VERSUS CIVILIANS",
  "COMMUNAL MILITIA VERSUS OTHER","SOLE RIOTER ACTION","RIOTERS VERSUS RIOTERS","RIOTERS VERSUS PROTESTERS","RIOTERS VERSUS CIVILIANS",
  "RIOTERS VERSUS OTHERS","SOLE PROTESTER ACTION","PROTESTERS VERSUS PROTESTERS","PROTESTERS VERSUS CIVILIANS","PROTESTERS VERSUS OTHER",
  "OTHER ACTOR VERSUS CIVILIANS","SOLE OTHER ACTION"]

df["interact"]=df["interaction"]

for i in range(len(key)):
    df.interact[df["interact"]==int(key[i])]=str(value[i].lower())
    
df.drop(columns="interaction",inplace=True)
# Out:
# c:\users\abdel\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head()
# Out:
#   event_date  year event_type         sub_event_type  \
# 0 2021-11-04  2021   Protests       Peaceful protest
# 1 2021-11-03  2021      Riots  Violent demonstration
# 2 2021-11-03  2021   Protests       Peaceful protest
# 3 2021-11-01  2021      Riots           Mob violence
# 4 2021-10-30  2021    Battles            Armed clash
#
#                                    actor1  inter1  \
# 0                      Protesters (Ghana)       6
# 1                         Rioters (Ghana)       5
# 2                      Protesters (Ghana)       6
# 3                         Rioters (Ghana)       5
# 4  Nadu Warriors Communal Militia (Ghana)       4
#
#                            actor2  inter2    admin1         admin2  \
# 0                             NaN       0   Eastern  Akwapem North
# 1  Police Forces of Ghana (2017-)       1   Central    Assin North
# 2                             NaN       0   Ashanti   Amansie West
# 3  Police Forces of Ghana (2017-)       1  Northern         Tamale
# 4  Police Forces of Ghana (2017-)       1   Eastern    Lower Manya
#
#        location  latitude  longitude                        source  \
# 0        Larteh    5.9395    -0.0689                   GNA (Ghana)
# 1  Assin Bereku    5.8678    -1.3389          Citi News; Ghana Web
# 2  Manso Atwere    6.4574    -1.8575                     Citi News
# 3        Tamale    9.4008    -0.8393                   GNA (Ghana)
# 4         Krobo    6.1299     0.0012  Ghana Web; Chronicle (Ghana)
#
#   source_scale                                              notes  fatalities  \
# 0     National  On 4 November 2021, members of the Presbyteria...           0
# 1     National  On 3 November 2021, workers of the Shimizu Dai...           0
# 2     National  On 3 November 2021, residents demonstrated in ...           0
# 3     National  On 1 November 2021, residents of Kukuo suburb ...           0
# 4     National  On 30 October 2021, members of the Nadu Warrio...           0
#
#                            interact
# 0             sole protester action
# 1           military versus rioters
# 2             sole protester action
# 3           military versus rioters
# 4  military versus communal militia

# %% [markdown]
# ### cleaning function
# > with these function we can go through another ACLED dataset automatically

# %%
 # define cleaning function 

def wrangle(file):
    
    # Load data
    dataset_name = file
    df = pd.read_csv(dataset_name, sep=";")
    
    # delete columns with more than 50% missing value
    df.drop(columns = ["assoc_actor_1","assoc_actor_2","admin3"], inplace =True)

    # delete columns with no useful information 
    df.drop(columns = ["event_id_cnty","region","iso3","country"], inplace=True)

    # convert event_date to datetime dtype
    dateFormatter = "%d %B %Y"
    df['event_date']=pd.to_datetime(df["event_date"], format=dateFormatter)

    # drop numeric features with no useful information 
    df.drop(columns = ["data_id", "iso", "event_id_no_cnty","time_precision","timestamp","geo_precision"] , inplace=True)
    
    # create new feature interact
    key = [10,11,12,13,14,15,16,17,18,20,22,23,24,25,26,27,28,30,33,34,35,36,37,38,40,44,45,46,47,48,50,55,56,57,58,60,66,67,68,78,80]

    value = ["SOLE MILITARY ACTION","MILITARY VERSUS MILITARY","MILITARY VERSUS REBELS","MILITARY VERSUS POLITICAL MILITIA",
  "MILITARY VERSUS COMMUNAL MILITIA","MILITARY VERSUS RIOTERS","MILITARY VERSUS PROTESTERS","MILITARY VERSUS CIVILIANS",
  "MILITARY VERSUS OTHER","SOLE REBEL ACTION","REBELS VERSUS REBELS","REBELS VERSUS POLITICAL MILIITA","REBELS VERSUS COMMUNAL MILITIA",
  "REBELS VERSUS RIOTERS","REBELS VERSUS PROTESTERS","REBELS VERSUS CIVILIANS","REBELS VERSUS OTHERS","SOLE POLITICAL MILITIA ACTION",
  "POLITICAL MILITIA VERSUS POLITICAL MILITIA","POLITICAL MILITIA VERSUS COMMUNAL MILITIA","POLITICAL MILITIA VERSUS RIOTERS",
  "POLITICAL MILITIA VERSUS PROTESTERS","POLITICAL MILITIA VERSUS CIVILIANS","POLITICAL MILITIA VERSUS OTHERS","SOLE COMMUNAL MILITIA ACTION",
  "COMMUNAL MILITIA VERSUS COMMUNAL MILITIA","COMMUNAL MILITIA VERSUS RIOTERS","COMMUNAL MILITIA VERSUS PROTESTERS","COMMUNAL MILITIA VERSUS CIVILIANS",
  "COMMUNAL MILITIA VERSUS OTHER","SOLE RIOTER ACTION","RIOTERS VERSUS RIOTERS","RIOTERS VERSUS PROTESTERS","RIOTERS VERSUS CIVILIANS",
  "RIOTERS VERSUS OTHERS","SOLE PROTESTER ACTION","PROTESTERS VERSUS PROTESTERS","PROTESTERS VERSUS CIVILIANS","PROTESTERS VERSUS OTHER",
  "OTHER ACTOR VERSUS CIVILIANS","SOLE OTHER ACTION"]

    df["interact"]=df["interaction"]

    for i in range(len(key)):
        df.interact[df["interact"]==int(key[i])]=str(value[i].lower())
        
    df.drop(columns="interaction",inplace=True)
    
    return df

# %%
data = wrangle('data/1980-11-04-2021-11-13-Ghana.csv')
data.head()
# Out:
# c:\users\abdel\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_date  year event_type         sub_event_type  \
# 0 2021-11-04  2021   Protests       Peaceful protest
# 1 2021-11-03  2021      Riots  Violent demonstration
# 2 2021-11-03  2021   Protests       Peaceful protest
# 3 2021-11-01  2021      Riots           Mob violence
# 4 2021-10-30  2021    Battles            Armed clash
#
#                                    actor1  inter1  \
# 0                      Protesters (Ghana)       6
# 1                         Rioters (Ghana)       5
# 2                      Protesters (Ghana)       6
# 3                         Rioters (Ghana)       5
# 4  Nadu Warriors Communal Militia (Ghana)       4
#
#                            actor2  inter2    admin1         admin2  \
# 0                             NaN       0   Eastern  Akwapem North
# 1  Police Forces of Ghana (2017-)       1   Central    Assin North
# 2                             NaN       0   Ashanti   Amansie West
# 3  Police Forces of Ghana (2017-)       1  Northern         Tamale
# 4  Police Forces of Ghana (2017-)       1   Eastern    Lower Manya
#
#        location  latitude  longitude                        source  \
# 0        Larteh    5.9395    -0.0689                   GNA (Ghana)
# 1  Assin Bereku    5.8678    -1.3389          Citi News; Ghana Web
# 2  Manso Atwere    6.4574    -1.8575                     Citi News
# 3        Tamale    9.4008    -0.8393                   GNA (Ghana)
# 4         Krobo    6.1299     0.0012  Ghana Web; Chronicle (Ghana)
#
#   source_scale                                              notes  fatalities  \
# 0     National  On 4 November 2021, members of the Presbyteria...           0
# 1     National  On 3 November 2021, workers of the Shimizu Dai...           0
# 2     National  On 3 November 2021, residents demonstrated in ...           0
# 3     National  On 1 November 2021, residents of Kukuo suburb ...           0
# 4     National  On 30 October 2021, members of the Nadu Warrio...           0
#
#                            interact
# 0             sole protester action
# 1           military versus rioters
# 2             sole protester action
# 3           military versus rioters
# 4  military versus communal militia

# %%
df.shape==data.shape
# Out:
# True

# %%
df.compare(data, align_axis=1, keep_shape=False, keep_equal=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
